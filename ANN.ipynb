# %%
import keras
# Out:
# C:\Users\virendra\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import tensorflow

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('ANN\Artificial_Neural_Networks\Churn_Modelling.csv')

# %%
dataset
# Out:
#       RowNumber  CustomerId         Surname  CreditScore Geography  Gender  \
# 0             1    15634602        Hargrave          619    France  Female
# 1             2    15647311            Hill          608     Spain  Female
# 2             3    15619304            Onio          502    France  Female
# 3             4    15701354            Boni          699    France  Female
# 4             5    15737888        Mitchell          850     Spain  Female
# 5             6    15574012             Chu          645     Spain    Male
# 6             7    15592531        Bartlett          822    France    Male
# 7             8    15656148          Obinna          376   Germany  Female
# 8             9    15792365              He          501    France    Male
# 9            10    15592389              H?          684    France    Male
# 10           11    15767821          Bearce          528    France    Male
# ...

# %%
X = dataset.iloc[:, 3:13].values
y = dataset.iloc[:, 13].values

# %%
X
# Out:
# array([[619, 'France', 'Female', ..., 1, 1, 101348.88],
#        [608, 'Spain', 'Female', ..., 0, 1, 112542.58],
#        [502, 'France', 'Female', ..., 1, 0, 113931.57],
#        ...,
#        [709, 'France', 'Female', ..., 0, 1, 42085.58],
#        [772, 'Germany', 'Male', ..., 1, 0, 92888.52],
#        [792, 'France', 'Female', ..., 1, 0, 38190.78]], dtype=object)

# %%
y
# Out:
# array([1, 0, 1, ..., 1, 1, 0], dtype=int64)

# %%
type(X)
# Out:
# numpy.ndarray

# %%
# Encoding categorical data
# Encoding the Independent Variable
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_X_1 = LabelEncoder()
X[:, 1] = labelencoder_X_1.fit_transform(X[:, 1])
labelencoder_X_2 = LabelEncoder()
X[:, 2] = labelencoder_X_2.fit_transform(X[:, 2])
onehotencoder = OneHotEncoder(categorical_features = [1])
X = onehotencoder.fit_transform(X).toarray()

# %%
X=X[:, 1:]

# %%
# splitting dataset into trainin and test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
#feature scalling
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
sc=StandardScaler()
x_train=sc.fit_transform(X_train)
x_test=sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier
clf=RandomForestClassifier(n_estimators=11)
clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=11, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
y_pre=clf.predict(x_test)

# %%
x_test.shape
# Out:
# (2000, 11)

# %%
from sklearn.model_selection import cross_val_score as csv

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pre)

# %%
y_pre=(y_pre>0.5)
unique_elements, counts_elements = np.unique(y_pre, return_counts=True)

# %% [markdown]
#  Predicting the Test set results
# y_pred = classifier.predict(X_test)
#
#  Making the Confusion Matrix
# from sklearn.metrics import confusion_matrix
# cm = confusion_matrix(y_test, y_pred)

# %%
cm
# Out:
# array([[1487,  108],
#        [ 185,  220]], dtype=int64)

# %%
1696/2000
# Out:
# 0.848

# %% [markdown]
# # part 2 ANN

# %%
from keras import Sequential

# %%
from keras.layers import Dense

# %%
from keras.layers import Dropout

# %%
#initializing an ANN

# %%
classifier = Sequential()

# %%
#adding input layer to classier and the first input layer 
classifier.add(Dense(output_dim=6,init='uniform',activation='relu',input_dim=11))
# Out:
# C:\Users\virendra\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", input_dim=11, units=6, kernel_initializer="uniform")`

# %%
classifier.add(Dropout(p=0.1))

# %%
classifier

# %%
#adding the second hidden layer
classifier.add(Dense(output_dim=6,init='uniform',activation='relu'))
# Out:
# C:\Users\virendra\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=6, kernel_initializer="uniform")`

# %%
#addu=ing the output layer
classifier.add(Dense(output_dim=1,init='uniform',activation='sigmoid'))
# Out:
# C:\Users\virendra\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=1, kernel_initializer="uniform")`

# %%
#compiling the ANN
classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
#fitting the ANN to the Training set
classifier.fit(X_train,y_train,batch_size=10,nb_epoch=100)
# Out:
# C:\Users\virendra\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Epoch 1/100
# 8000/8000 [==============================] - 3s 397us/step - loss: 0.4797 - acc: 0.7959
# Epoch 2/100
# 8000/8000 [==============================] - 1s 155us/step - loss: 0.4276 - acc: 0.7960
# Epoch 3/100
# 8000/8000 [==============================] - 1s 159us/step - loss: 0.4222 - acc: 0.7999
# Epoch 4/100
# 8000/8000 [==============================] - 1s 145us/step - loss: 0.4182 - acc: 0.8214
# Epoch 5/100
# 8000/8000 [==============================] - 1s 147us/step - loss: 0.4162 - acc: 0.8266
# Epoch 6/100
# 8000/8000 [==============================] - 1s 145us/step - loss: 0.4142 - acc: 0.8297
# Epoch 7/100
# 8000/8000 [==============================] - 1s 154us/step - loss: 0.4129 - acc: 0.8314
# Epoch 8/100
# 8000/8000 [==============================] - 1s 171us/step - loss: 0.4114 - acc: 0.8314
# Epoch 9/100
# ...

# %%
#part 3-Making the prediction ptobability

# %%
X_test.shape
# Out:
# (2000, 11)

# %%
y_pred=classifier.predict(X_test)

# %%
y_pred=(y_pred>0.5)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
cm
# Out:
# array([[1550,   45],
#        [ 270,  135]], dtype=int64)

# %%
(1545+141)/2000
# Out:
# 0.843

# %%
#part4 predict single member decisiion

# %%
cred={
    "yup":0.0,
    "Geography":0,
    "Credit Score": 600,
    "Gender": 1,
    "Age": 40,
    "Tenure": 3,
    "Balance": 60000,
    "Number of Products": 2,
    "Does this customer have a credit card ": "Yes",
    "Is this customer an Active Member": "Yes",
    "Estimated Salary":50000}

# %%
(cred.keys())
# Out:
# dict_keys(['yup', 'Geography', 'Credit Score', 'Gender', 'Age', 'Tenure', 'Balance', 'Number of Products', 'Does this customer have a credit card ', 'Is this customer an Active Member', 'Estimated Salary'])

# %%
ke=[]
val=[]
c=0
for key, value in cred.items():
    ke.append(key)
    val.append(value)
    c+=1

# %%
people=[]
for i in range(len(ke)):
    people.append([ke[i],val[i]])

# %%
people
# Out:
# [['yup', 0.0],
#  ['Geography', 0],
#  ['Credit Score', 600],
#  ['Gender', 1],
#  ['Age', 40],
#  ['Tenure', 3],
#  ['Balance', 60000],
#  ['Number of Products', 2],
#  ['Does this customer have a credit card ', 'Yes'],
#  ['Is this customer an Active Member', 'Yes'],
#  ['Estimated Salary', 50000]]

# %%
ke
# Out:
# ['yup',
#  'Geography',
#  'Credit Score',
#  'Gender',
#  'Age',
#  'Tenure',
#  'Balance',
#  'Number of Products',
#  'Does this customer have a credit card ',
#  'Is this customer an Active Member',
#  'Estimated Salary']

# %%
X=np.array(ke).reshape(1,11)
y=np.array(val).reshape(1,11)

# %%
y
# Out:
# array([['0.0', '0', '600', '1', '40', '3', '60000', '2', 'Yes', 'Yes',
#         '50000']], dtype='<U32')

# %%
df = pd.DataFrame(y,columns=ke)
df
# Out:
#    yup Geography Credit Score Gender Age Tenure Balance Number of Products  \
# 0  0.0         0          600      1  40      3   60000                  2
#
#   Does this customer have a credit card  Is this customer an Active Member  \
# 0                                    Yes                               Yes
#
#   Estimated Salary
# 0            50000

# %%
df=np.array(df)
df.shape
# Out:
# (1, 11)

# %%
# Encoding categorical data
# Encoding the Independent Variable
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_df_1 = LabelEncoder()
df[:, 2] = labelencoder_df_1.fit_transform(df[:, 2])

# %%
labelencoder_df_2 = LabelEncoder()
df[:, 9] = labelencoder_df_2.fit_transform(df[:, 9])
labelencoder_df_3 = LabelEncoder()
df[:, 8] = labelencoder_df_3.fit_transform(df[:, 8])

# %%
XX=df
XX
# Out:
# array([['0.0', '0', '600', '1', '40', '3', '60000', '2', 0, 0, '50000']],
#       dtype=object)

# %%
onehotencoder = OneHotEncoder(categorical_features = [1])
XX = onehotencoder.fit_transform(XX).toarray()
XX
# Out:
# array([[1.e+00, 0.e+00, 6.e+02, 1.e+00, 4.e+01, 3.e+00, 6.e+04, 2.e+00,
#         0.e+00, 0.e+00, 5.e+04]])

# %%
sc.transform(XX)
# Out:
# array([[ 1.00000000e+00, -1.09065534e-16,  6.00000000e+02,
#          1.00000000e+00,  4.00000000e+01,  3.00000000e+00,
#          6.00000000e+04,  2.00000000e+00,  1.31034072e-16,
#          2.78665979e-17,  5.00000000e+04]])

# %%
npred=classifier.predict(XX)

# %%
npred=(npred>0.5)

# %%
npred
# Out:
# array([[False]])

# %%
#Evaluating the ANN

# %%
from keras.wrappers.scikit_learn import KerasClassifier

# %%
from sklearn.model_selection import cross_val_score

# %%
def build_classifier():
    classifier = Sequential()
    classifier.add(Dense(output_dim=6,init='uniform',activation='relu',input_dim=11))
    classifier.add(Dense(output_dim=6,init='uniform',activation='relu'))
    classifier.add(Dense(output_dim=1,init='uniform',activation='sigmoid'))
    classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
    return classifier

# %%
classifier=KerasClassifier(build_fn=build_classifier,batch_size=10,nb_epoch=100)

# %%
accuracies=cross_val_score(estimator=classifier,X=X_train,y=y_train,cv=10,n_jobs=-1)

# %%
accuracies.mean()

# %%
#parameter tuning
